# %%
import pandas as pd
import dask.dataframe as dd
import matplotlib.pyplot as plt

# %%
df = dd.read_csv("*.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\dask\backends.py:140, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     139 try:
# --> 140     return func(*args, **kwargs)
#     141 except Exception as e:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\dask\dataframe\io\csv.py:728, in make_reader.<locals>.read(urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     715 def read(
#     716     urlpath,
#     717     blocksize="default",
#    (...)    726     **kwargs,
#     727 ):
# --> 728     return read_pandas(
#     729         reader,
#     730         urlpath,
#     731         blocksize=blocksize,
#     732         lineterminator=lineterminator,
# ...
